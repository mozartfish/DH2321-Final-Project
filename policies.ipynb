# %%
import pandas as pd

# %%
df = pd.read_csv('./data0/policies.csv')
df.head()
# Out:
#    country  year                                             policy  \
# 0  Austria  2005                   EU Emission Trading Scheme (ETS)
# 1  Austria  1993              Domestic Environmental Support Scheme
# 2  Austria  2007                   Austrian Climate and Energy Fund
# 3  Austria  2002  Increase the share of renewable energy in powe...
# 4  Austria  2008  Increase energy efficiency in energy and manuf...
#
#                                          description       status  \
# 0  The objective is to limit the CO2 emission fro...  Implemented
# 1  The objective of the Domestic Environmental Su...  Implemented
# 2  In 2007, the Federal Government established a ...  Implemented
# 3  Beyond the traditional use of large-scale hydr...  Implemented
# 4  Based on EU legislation, Austria has implement...  Implemented
#
#                                               sector  \
# 0  Energy consumption; Energy supply; Industrial ...
# ...

# %%
# Remove all rows with year=0
df = df[df['year'] != 0]

df.to_csv('policies.csv', index=False)
df.head()
# Out:
#    country  year                                             policy  \
# 0  Austria  2005                   EU Emission Trading Scheme (ETS)
# 1  Austria  1993              Domestic Environmental Support Scheme
# 2  Austria  2007                   Austrian Climate and Energy Fund
# 3  Austria  2002  Increase the share of renewable energy in powe...
# 4  Austria  2008  Increase energy efficiency in energy and manuf...
#
#                                          description       status  \
# 0  The objective is to limit the CO2 emission fro...  Implemented
# 1  The objective of the Domestic Environmental Su...  Implemented
# 2  In 2007, the Federal Government established a ...  Implemented
# 3  Beyond the traditional use of large-scale hydr...  Implemented
# 4  Based on EU legislation, Austria has implement...  Implemented
#
#                                               sector  \
# 0  Energy consumption; Energy supply; Industrial ...
# ...
